-- %% [markdown]
-- # [CadastroImovel]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [CadastroImovel]    Script Date: 03/09/2020 16:56:32 ******/
CREATE DATABASE [CadastroImovel]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'CadastroImovel', FILENAME = N'C:\Users\Gabriel\OneDrive\Pris\ProgramaAluguel\database\CadastroImovel.mdf' , SIZE = 3072KB , MAXSIZE = UNLIMITED, FILEGROWTH = 1024KB )
 LOG ON 
( NAME = N'CadastroImovel_log', FILENAME = N'C:\Users\Gabriel\OneDrive\Pris\ProgramaAluguel\database\CadastroImovel_log.ldf' , SIZE = 1024KB , MAXSIZE = 2048GB , FILEGROWTH = 10%)
GO
ALTER DATABASE [CadastroImovel] SET COMPATIBILITY_LEVEL = 120
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [CadastroImovel].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [CadastroImovel] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [CadastroImovel] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [CadastroImovel] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [CadastroImovel] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [CadastroImovel] SET ARITHABORT OFF 
GO
ALTER DATABASE [CadastroImovel] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [CadastroImovel] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [CadastroImovel] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [CadastroImovel] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [CadastroImovel] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [CadastroImovel] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [CadastroImovel] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [CadastroImovel] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [CadastroImovel] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [CadastroImovel] SET  DISABLE_BROKER 
GO
ALTER DATABASE [CadastroImovel] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [CadastroImovel] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [CadastroImovel] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [CadastroImovel] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [CadastroImovel] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [CadastroImovel] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [CadastroImovel] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [CadastroImovel] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [CadastroImovel] SET  MULTI_USER 
GO
ALTER DATABASE [CadastroImovel] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [CadastroImovel] SET DB_CHAINING OFF 
GO
ALTER DATABASE [CadastroImovel] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [CadastroImovel] SET TARGET_RECOVERY_TIME = 0 SECONDS 
GO
ALTER DATABASE [CadastroImovel] SET DELAYED_DURABILITY = DISABLED 
GO

-- %% [markdown]
-- # [dbo].[Cadastro]

-- %%
USE [CadastroImovel]
GO

-- %%
/****** Object:  Table [dbo].[Cadastro]    Script Date: 03/09/2020 16:56:33 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cadastro](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[rua] [nvarchar](50) NOT NULL,
	[numero] [nvarchar](10) NOT NULL,
	[complemento] [nvarchar](50) NULL,
	[bairro] [nvarchar](50) NULL,
	[cidade] [nvarchar](50) NOT NULL,
	[estado] [nchar](2) NOT NULL,
	[cep] [nchar](9) NULL,
	[tipo_imovel] [nvarchar](50) NULL,
	[area] [int] NOT NULL,
	[valor_aluguel] [float] NOT NULL,
	[n_banheiros] [int] NULL,
	[n_quartos] [int] NULL,
	[n_vagas_garagem] [int] NULL,
	[vetor_distancias] [nvarchar](50) NULL,
	[vetor_outros] [nvarchar](50) NULL,
 CONSTRAINT [PK_Cadastros] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [CadastroImovel]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [CadastroImovel] SET  READ_WRITE 
GO
